# %% [markdown]
# # (실습) 생활코딩: CSS

# %% [markdown]
# **과제 1**

# %% [markdown]
# 아래 사이트의 동영상을 모두 시청하고 학습하고 GitHub Pages에서 실습한 내용을 ppt 로 만들어라.
#
# [생활 코딩 CSS](https://opentutorials.org/course/3086)
#
# 제출 내용: 구글 프레젠테이션의 ppt 링크
