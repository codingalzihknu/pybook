# %% [markdown]
# # 반복문

# %% [markdown]
# 특정 명령문을 반복<font size="2">iteration</font> 실행하는 장치인
# 반복문<font size="2">loop statement</font>을 소개한다.

# %% [markdown]
# ## for 반복문

# %% [markdown]
# ## while 반복문
